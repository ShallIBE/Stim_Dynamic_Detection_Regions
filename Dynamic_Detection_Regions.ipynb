# %% [markdown]
# # Dynamic Detection Regions
# This cell assumes your loaded Stim circuit is named `circuit`.

# %%
from dynamic_detection_regions import dynamic_detection_regions
import stim 

circuit= stim.Circuit.generated(code_task='surface_code:rotated_memory_z',distance=21,rounds=3)
dynamic_detection_regions(circuit)
# Out:
# Dynamic detection regions (live; built in 1.753s; 25.3 MB in memory)
