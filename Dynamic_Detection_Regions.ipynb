# %% [markdown]
# # Dynamic Detection Regions
#
# Distance-9 rotated surface-code Z-memory example.

# %%
import stim
from dynamic_detection_regions import dynamic_detection_regions

circuit = stim.Circuit.generated(code_task='surface_code:rotated_memory_z', distance=9, rounds=9)
dynamic_detection_regions(circuit)
